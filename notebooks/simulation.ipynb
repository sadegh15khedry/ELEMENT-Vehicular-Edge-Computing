# %%
import sys
import os

sys.path.append('../src/scripts')
sys.path.append('../src/classes')
from simulation import Simulation

# %%
config_file = '../config.json'
algorithm = 'proposed'
time_step = 1 # in milliseconds
max_iterations = 10
mobility_file_path = '../src/sumo/csv/hello.csv'
simulation = Simulation(config_file, algorithm, time_step, max_iterations, mobility_file_path);
# Out:
# Edge Server id: 1, x: 100 y: 200
# Edge Server id: 2, x: 100 y: 200
# Edge Server id: 3, x: 100 y: 200
# Initialized 3 edge servers.
# vehicle id: 1 x: 100 y: 200 speed: 4000, direction: 1000
# Initialized 1 vehicles.

# %%
simulation.run()
# Out:
# Running simulation stated!
# Iteration: 1 started at 1730305400.1786265 ----------------------------------------------------------------
# Task ID: 1, Execution Time: 5 seconds
# id: 1, x: 6.1, y: -1.65, speed: 1.0, direction: 90.0
# undecided tasks count: 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 simulation.run()
#
# File /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/scripts/simulation.py:66, in Simulation.run(self)
#      64 generate_tasks(self.vehicles, self.iteration_count)
#      65 vehicle_movement_funciton(self.vehicles, self.iteration_count, self.mobilty_file)
# ---> 66 manage_tasks(self.vehicles, self.edge_servers, self.iteration_count)
#      69 time.sleep(self.time_step)
#      70 print(f"Iteration: {self.iteration_count} started at {iteration_start_time} ----------------------------------------------------------------")
#
# File /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/scripts/task_management.py:30, in manage_tasks(vehicles, edge_servers, time)
#      26 def manage_tasks(vehicles, edge_servers, time):
#      29     for vehicle in vehicles:
# ---> 30         handle_undecided_tasks(vehicle, edge_servers)
#      31         is_busy = vehicle.is_busy(time)
#      32         if is_busy == False:
#
# File /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/scripts/task_management.py:12, in handle_undecided_tasks(vehicle, edge_servers)
#      10 def handle_undecided_tasks(vehicle, edge_servers):
#      11     for task in vehicle.undecided_tasks:
# ---> 12         action = vehicle.agent.choose_action(task, len(vehicle.local_execution_queue))
#      13         vehicle.undecided.remove(task)
#      14         if(action == 0):
#
# File /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/classes/reinforcement_learning_agent.py:70, in ReinforcementLearnigAgent.choose_action(self, task, queue_lenght)
#      66 def choose_action(self, task, queue_lenght):#state_indices
#      67     # state_indices
#      68     state_indices = (self.discretize_task_size(task.size),
#      69                      self.discretize_execution_time(task.execution_time),
# ---> 70                      self.discretize_queue_length(queue_lenght))
#      72     if np.random.rand() < self.epsilon:
#      73         action = np.random.choice(self.actions)
#
# File /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/classes/reinforcement_learning_agent.py:55, in ReinforcementLearnigAgent.discretize_queue_length(self, queue_length)
#      54 def discretize_queue_length(self, queue_length):
# ---> 55     if 0 <= queue_length <= self.max_queue_length:
#      56         return int(queue_length)
#      57     else:
#
# AttributeError: 'ReinforcementLearnigAgent' object has no attribute 'max_queue_length'
