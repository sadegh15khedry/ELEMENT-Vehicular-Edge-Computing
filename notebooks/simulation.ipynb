# %%
import sys
import os

sys.path.append('../src/scripts')
sys.path.append('../src/classes')
from simulation import Simulation

# %%
# config_file = '../config.json'
algorithm = 'proposed'
time_step_length = 1 # in milliseconds
max_iterations = 1000000
mobility_file_path = '../src/sumo/csv/train_single.csv'
edge_file_path = '../src/inputs/train/edge_servers.json'
vehicle_file_path = '../src/inputs/train/vehicles_single.json'
mode = 'train'
should_update_q_table = False
report_path = '../results/reports/report.csv'
simulation = Simulation(algorithm, time_step_length, max_iterations, mobility_file_path, mode, edge_file_path, vehicle_file_path, report_path)

# %%
simulation.run()
