# %%
import sys
import os

sys.path.append('../src/scripts')
sys.path.append('../src/classes')
from simulation import Simulation

# %%
config_file = '../config.json'
algorithm = 'proposed'
time_step_length = 1 # in milliseconds
max_iterations = 100
mobility_file_path = '../src/sumo/csv/hello.csv'
simulation = Simulation(config_file, algorithm, time_step_length, max_iterations, mobility_file_path);
# Out:
# Edge Server id: 1, x: 100 y: 200
# Edge Server id: 2, x: 100 y: 200
# Edge Server id: 3, x: 100 y: 200
# Initialized 3 edge servers.
# vehicle id: 1 x: 100 y: 200 speed: 4000, direction: 1000
# Initialized 1 vehicles.

# %%
simulation.run()
# Out:
# Running simulation stated!
# Task ID: 1, Execution Time: 5 seconds
# task:1 is genenrated in the vehicle:1
# Iteration: 1 started at 1730362653.7207468 ----------------------------------------------------------------
# task 1 has been assigned to local
# task:1 is now processing on vehicle:1
# Iteration: 2 ended at 1730362653.7207468 ----------------------------------------------------------------
# Iteration: 2 started at 1730362654.7274768 ----------------------------------------------------------------
# Iteration: 3 ended at 1730362654.7274768 ----------------------------------------------------------------
# Iteration: 3 started at 1730362655.7310479 ----------------------------------------------------------------
# Iteration: 4 ended at 1730362655.7310479 ----------------------------------------------------------------
# Iteration: 4 started at 1730362656.7376893 ----------------------------------------------------------------
# Iteration: 5 ended at 1730362656.7376893 ----------------------------------------------------------------
# Iteration: 5 started at 1730362657.7435067 ----------------------------------------------------------------
# Iteration: 6 ended at 1730362657.7435067 ----------------------------------------------------------------
# Iteration: 6 started at 1730362658.7489245 ----------------------------------------------------------------
# task:1 is finished processing on vehicle:1
# Iteration: 7 ended at 1730362658.7489245 ----------------------------------------------------------------
# Iteration: 7 started at 1730362659.7572675 ----------------------------------------------------------------
# Iteration: 8 ended at 1730362659.7572675 ----------------------------------------------------------------
# Iteration: 8 started at 1730362660.765378 ----------------------------------------------------------------
# Iteration: 9 ended at 1730362660.765378 ----------------------------------------------------------------
# Iteration: 9 started at 1730362661.788615 ----------------------------------------------------------------
# Iteration: 10 ended at 1730362661.788615 ----------------------------------------------------------------
# Iteration: 10 started at 1730362662.7985666 ----------------------------------------------------------------
# Iteration: 11 ended at 1730362662.7985666 ----------------------------------------------------------------
# Iteration: 11 started at 1730362663.8220308 ----------------------------------------------------------------
# Iteration: 12 ended at 1730362663.8220308 ----------------------------------------------------------------
# Iteration: 12 started at 1730362664.832216 ----------------------------------------------------------------
# Iteration: 13 ended at 1730362664.832216 ----------------------------------------------------------------
# Iteration: 13 started at 1730362665.8558729 ----------------------------------------------------------------
# Iteration: 14 ended at 1730362665.8558729 ----------------------------------------------------------------
# Iteration: 14 started at 1730362666.8634322 ----------------------------------------------------------------
# Iteration: 15 ended at 1730362666.8634322 ----------------------------------------------------------------
# Iteration: 15 started at 1730362667.8856711 ----------------------------------------------------------------
# Iteration: 16 ended at 1730362667.8856711 ----------------------------------------------------------------
# Iteration: 16 started at 1730362668.8932714 ----------------------------------------------------------------
# Iteration: 17 ended at 1730362668.8932714 ----------------------------------------------------------------
# Iteration: 17 started at 1730362669.9147277 ----------------------------------------------------------------
# Iteration: 18 ended at 1730362669.9147277 ----------------------------------------------------------------
# Iteration: 18 started at 1730362670.9209237 ----------------------------------------------------------------
# Iteration: 19 ended at 1730362670.9209237 ----------------------------------------------------------------
# Iteration: 19 started at 1730362671.9408383 ----------------------------------------------------------------
# Iteration: 20 ended at 1730362671.9408383 ----------------------------------------------------------------
# Iteration: 20 started at 1730362672.9455664 ----------------------------------------------------------------
# Iteration: 21 ended at 1730362672.9455664 ----------------------------------------------------------------
# Iteration: 21 started at 1730362673.9501622 ----------------------------------------------------------------
# Iteration: 22 ended at 1730362673.9501622 ----------------------------------------------------------------
# Iteration: 22 started at 1730362674.9661648 ----------------------------------------------------------------
# Iteration: 23 ended at 1730362674.9661648 ----------------------------------------------------------------
# Iteration: 23 started at 1730362675.9829502 ----------------------------------------------------------------
# Iteration: 24 ended at 1730362675.9829502 ----------------------------------------------------------------
# Iteration: 24 started at 1730362676.9986546 ----------------------------------------------------------------
# Iteration: 25 ended at 1730362676.9986546 ----------------------------------------------------------------
# Iteration: 25 started at 1730362678.0059862 ----------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 simulation.run()
#
# File /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/scripts/simulation.py:70, in Simulation.run(self)
#      66 vehicle_movement_funciton(self.vehicles, self.iteration_count, self.mobilty_file)
#      67 manage_tasks(self.vehicles, self.edge_servers, self.iteration_count)
# ---> 70 time.sleep(self.time_step_length)
#      71 self.iteration_count += 1
#      72 print(f"Iteration: {self.iteration_count} ended at {iteration_start_time} ----------------------------------------------------------------")
#
# KeyboardInterrupt:
