# %%
import sys
import os

sys.path.append('../src/scripts')
sys.path.append('../src/classes')
from simulation import Simulation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 sys.path.append('../src/scripts')
#       5 sys.path.append('../src/classes')
# ----> 6 from simulation import Simulation
#
# File /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/scripts/simulation.py:7
#       5 from vehicle import Vehicle
#       6 from edge_server import EdgeServer
# ----> 7 from vehicle_movement import load_mobility_csv, vehicle_movement_funciton
#       8 # from task_management import manage_runnig_task
#       9 from task_management import vehicles_task_generation
#
# File /mnt/c/Sadegh/codes/Computer-Science-Paper/notebooks/../src/scripts/vehicle_movement.py:2
# ----> 2 import pandas as pd
#       4 def move_vehicle(vehicle, time_step_movements):
#       5     vehicle_movement_info = time_step_movements[time_step_movements['vehicle_id'] == vehicle.id]
#
# ModuleNotFoundError: No module named 'pandas'

# %%
config_file = '../config.json'
algorithm = 'proposed'
time_step = 1 # in milliseconds
max_iterations = 10
mobility_file_path = '../src/sumo/csv/hello.csv'
simulation = Simulation(config_file, algorithm, time_step, max_iterations, mobility_file_path);

# %%
simulation.run()
