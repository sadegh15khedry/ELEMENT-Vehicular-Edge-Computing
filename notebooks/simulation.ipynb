# %%
import sys
import os

sys.path.append('../src/scripts')
sys.path.append('../src/classes')
from simulation import Simulation

# %%
config_file = '../config.json'
algorithm = 'proposed'
time_step = 1 # in milliseconds
max_iterations = 10
mobility_file_path = '../src/sumo/csv/hello.csv'
simulation = Simulation(config_file, algorithm, time_step, max_iterations, mobility_file_path);
# Out:
# Edge Server id: 1, x: 100 y: 200
# Edge Server id: 2, x: 100 y: 200
# Edge Server id: 3, x: 100 y: 200
# Initialized 3 edge servers.
# vehicle id: 1 x: 100 y: 200 speed: 4000, direction: 1000
# Initialized 1 vehicles.

# %%
simulation.run()
# Out:
# Running simulation stated!
# Iteration: 1 started at 1730205118.9607975 ----------------------------------------------------------------
# Task ID: 1, Execution Time: 10 seconds
# id: 1, x: 6.1, y: -1.65, speed: 1.0, direction: 90.0
# undecided tasks count: 1
# Iteration: 1 started at 1730205118.9607975 ----------------------------------------------------------------
# Iteration: 2 started at 1730205119.9663227 ----------------------------------------------------------------
# Task ID: 2, Execution Time: 10 seconds
# id: 1, x: 8.1, y: -1.65, speed: 2.0, direction: 90.0
# undecided tasks count: 2
# Iteration: 2 started at 1730205119.9663227 ----------------------------------------------------------------
# Iteration: 3 started at 1730205120.9705088 ----------------------------------------------------------------
# Task ID: 3, Execution Time: 10 seconds
# id: 1, x: 11.1, y: -1.65, speed: 3.0, direction: 90.0
# undecided tasks count: 3
# Iteration: 3 started at 1730205120.9705088 ----------------------------------------------------------------
# Iteration: 4 started at 1730205121.974589 ----------------------------------------------------------------
# Task ID: 4, Execution Time: 10 seconds
# id: 1, x: 15.1, y: -1.65, speed: 4.0, direction: 90.0
# undecided tasks count: 4
# Iteration: 4 started at 1730205121.974589 ----------------------------------------------------------------
# Iteration: 5 started at 1730205122.9803555 ----------------------------------------------------------------
# Task ID: 5, Execution Time: 10 seconds
# id: 1, x: 20.1, y: -1.65, speed: 5.0, direction: 90.0
# undecided tasks count: 5
# Iteration: 5 started at 1730205122.9803555 ----------------------------------------------------------------
# Iteration: 6 started at 1730205123.9831347 ----------------------------------------------------------------
# Task ID: 6, Execution Time: 10 seconds
# id: 1, x: 26.1, y: -1.65, speed: 6.0, direction: 90.0
# undecided tasks count: 6
# Iteration: 6 started at 1730205123.9831347 ----------------------------------------------------------------
# Iteration: 7 started at 1730205124.9865825 ----------------------------------------------------------------
# Task ID: 7, Execution Time: 10 seconds
# id: 1, x: 33.1, y: -1.65, speed: 7.0, direction: 90.0
# undecided tasks count: 7
# Iteration: 7 started at 1730205124.9865825 ----------------------------------------------------------------
# Iteration: 8 started at 1730205125.992768 ----------------------------------------------------------------
# Task ID: 8, Execution Time: 10 seconds
# id: 1, x: 41.1, y: -1.65, speed: 8.0, direction: 90.0
# undecided tasks count: 8
# Iteration: 8 started at 1730205125.992768 ----------------------------------------------------------------
# Iteration: 9 started at 1730205126.9955037 ----------------------------------------------------------------
# Task ID: 9, Execution Time: 10 seconds
# id: 1, x: 50.1, y: -1.65, speed: 9.0, direction: 90.0
# undecided tasks count: 9
# Iteration: 9 started at 1730205126.9955037 ----------------------------------------------------------------
# Iteration: 10 started at 1730205128.0023458 ----------------------------------------------------------------
# Task ID: 10, Execution Time: 10 seconds
# id: 1, x: 60.1, y: -1.65, speed: 10.0, direction: 90.0
# undecided tasks count: 10
# Iteration: 10 started at 1730205128.0023458 ----------------------------------------------------------------
# Iteration: 11 started at 1730205129.0048385 ----------------------------------------------------------------
# Task ID: 11, Execution Time: 10 seconds
# id: 1, x: 71.1, y: -1.65, speed: 11.0, direction: 90.0
# undecided tasks count: 11
# Iteration: 11 started at 1730205129.0048385 ----------------------------------------------------------------
# Simulation finished! Total execution time: 11.046943426132202 seconds.
