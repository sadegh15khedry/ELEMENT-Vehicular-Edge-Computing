# %%
import sys
import os

sys.path.append('../src/scripts')
sys.path.append('../src/classes')
from simulation import Simulation

# %%
config_file = '../config.json'
algorithm = 'proposed'
time_step = 1 # in milliseconds
max_iterations = 10
mobility_file_path = '../src/sumo/csv/hello.csv'
simulation = Simulation(config_file, algorithm, time_step, max_iterations, mobility_file_path);
# Out:
# Edge Server id: 1, x: 100 y: 200
# Edge Server id: 2, x: 100 y: 200
# Edge Server id: 3, x: 100 y: 200
# Initialized 3 edge servers.
# vehicle id: 1 x: 100 y: 200 speed: 4000, direction: 1000
# Initialized 1 vehicles.

# %%
simulation.run()
# Out:
# Running simulation stated!
# Iteration: 1 started at 1730359349.604109 ----------------------------------------------------------------
# Task ID: 1, Execution Time: 5 seconds
# id: 1, x: 6.1, y: -1.65, speed: 1.0, direction: 90.0
# undecided tasks count: 1
# task 1 has been assigned to edge server 1
# Iteration: 1 started at 1730359349.604109 ----------------------------------------------------------------
# Iteration: 2 started at 1730359350.6266763 ----------------------------------------------------------------
# Task ID: 2, Execution Time: 5 seconds
# id: 1, x: 8.1, y: -1.65, speed: 2.0, direction: 90.0
# undecided tasks count: 1
# task 2 has been assigned to edge server 1
# Iteration: 2 started at 1730359350.6266763 ----------------------------------------------------------------
# Iteration: 3 started at 1730359351.6420593 ----------------------------------------------------------------
# Task ID: 3, Execution Time: 5 seconds
# id: 1, x: 11.1, y: -1.65, speed: 3.0, direction: 90.0
# undecided tasks count: 1
# task 3 has been assigned to edge server 1
# Iteration: 3 started at 1730359351.6420593 ----------------------------------------------------------------
# Iteration: 4 started at 1730359352.648403 ----------------------------------------------------------------
# Task ID: 4, Execution Time: 5 seconds
# id: 1, x: 15.1, y: -1.65, speed: 4.0, direction: 90.0
# undecided tasks count: 1
# task 4 has been assigned to edge server 1
# Iteration: 4 started at 1730359352.648403 ----------------------------------------------------------------
# Iteration: 5 started at 1730359353.6611493 ----------------------------------------------------------------
# Task ID: 5, Execution Time: 5 seconds
# id: 1, x: 20.1, y: -1.65, speed: 5.0, direction: 90.0
# undecided tasks count: 1
# task 5 has been assigned to local
# Iteration: 5 started at 1730359353.6611493 ----------------------------------------------------------------
# Iteration: 6 started at 1730359354.6747208 ----------------------------------------------------------------
# Task ID: 6, Execution Time: 5 seconds
# id: 1, x: 26.1, y: -1.65, speed: 6.0, direction: 90.0
# undecided tasks count: 1
# task 6 has been assigned to edge server 1
# Iteration: 6 started at 1730359354.6747208 ----------------------------------------------------------------
# Iteration: 7 started at 1730359355.6904912 ----------------------------------------------------------------
# Task ID: 7, Execution Time: 5 seconds
# id: 1, x: 33.1, y: -1.65, speed: 7.0, direction: 90.0
# undecided tasks count: 1
# task 7 has been assigned to local
# Iteration: 7 started at 1730359355.6904912 ----------------------------------------------------------------
# Iteration: 8 started at 1730359356.7053096 ----------------------------------------------------------------
# Task ID: 8, Execution Time: 5 seconds
# id: 1, x: 41.1, y: -1.65, speed: 8.0, direction: 90.0
# undecided tasks count: 1
# task 8 has been assigned to local
# Iteration: 8 started at 1730359356.7053096 ----------------------------------------------------------------
# Iteration: 9 started at 1730359357.7209163 ----------------------------------------------------------------
# Task ID: 9, Execution Time: 5 seconds
# id: 1, x: 50.1, y: -1.65, speed: 9.0, direction: 90.0
# undecided tasks count: 1
# task 9 has been assigned to local
# Iteration: 9 started at 1730359357.7209163 ----------------------------------------------------------------
# Iteration: 10 started at 1730359357.9583557 ----------------------------------------------------------------
# Task ID: 10, Execution Time: 5 seconds
# id: 1, x: 60.1, y: -1.65, speed: 10.0, direction: 90.0
# undecided tasks count: 1
# task 10 has been assigned to edge server 1
# Iteration: 10 started at 1730359357.9583557 ----------------------------------------------------------------
# Iteration: 11 started at 1730359358.9734101 ----------------------------------------------------------------
# Task ID: 11, Execution Time: 5 seconds
# id: 1, x: 71.1, y: -1.65, speed: 11.0, direction: 90.0
# undecided tasks count: 1
# task 11 has been assigned to local
# Iteration: 11 started at 1730359358.9734101 ----------------------------------------------------------------
# Simulation finished! Total execution time: 10.385662317276001 seconds.
